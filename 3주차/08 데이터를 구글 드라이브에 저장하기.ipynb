# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import requests
import pandas as pd
import json

# %%
url = "https://api.upbit.com/v1/candles/weeks?market=KRW-BTC&count=200"

headers = {"accept": "application/json"}

response = requests.get(url, headers=headers)

btc_df = pd.DataFrame(json.loads(response.text))
btc_df
# Out:
#       market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0    KRW-BTC  2024-01-15T00:00:00  2024-01-15T09:00:00     57380000.0
# 1    KRW-BTC  2024-01-08T00:00:00  2024-01-08T09:00:00     59105000.0
# 2    KRW-BTC  2024-01-01T00:00:00  2024-01-01T09:00:00     57045000.0
# 3    KRW-BTC  2023-12-25T00:00:00  2023-12-25T09:00:00     58002000.0
# 4    KRW-BTC  2023-12-18T00:00:00  2023-12-18T09:00:00     56710000.0
# ..       ...                  ...                  ...            ...
# 195  KRW-BTC  2020-04-20T00:00:00  2020-04-20T09:00:00      8660000.0
# 196  KRW-BTC  2020-04-13T00:00:00  2020-04-13T09:00:00      8464000.0
# 197  KRW-BTC  2020-04-06T00:00:00  2020-04-06T09:00:00      8198000.0
# 198  KRW-BTC  2020-03-30T00:00:00  2020-03-30T09:00:00      7218000.0
# 199  KRW-BTC  2020-03-23T00:00:00  2020-03-23T09:00:00      7379000.0
#
#      high_price   low_price  trade_price      timestamp  \
# 0    59577000.0  55935000.0   57485000.0  1705810819376
# ...

# %%
weeks_path = "/content/drive/MyDrive/coin_data/weeks"

# %%
btc_df.to_csv(weeks_path + "/krw_btc.csv", index=False)

# %%
load_btc_df = pd.read_csv(weeks_path + "/krw_btc.csv")
load_btc_df
# Out:
#       market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0    KRW-BTC  2024-01-15T00:00:00  2024-01-15T09:00:00     57380000.0
# 1    KRW-BTC  2024-01-08T00:00:00  2024-01-08T09:00:00     59105000.0
# 2    KRW-BTC  2024-01-01T00:00:00  2024-01-01T09:00:00     57045000.0
# 3    KRW-BTC  2023-12-25T00:00:00  2023-12-25T09:00:00     58002000.0
# 4    KRW-BTC  2023-12-18T00:00:00  2023-12-18T09:00:00     56710000.0
# ..       ...                  ...                  ...            ...
# 195  KRW-BTC  2020-04-20T00:00:00  2020-04-20T09:00:00      8660000.0
# 196  KRW-BTC  2020-04-13T00:00:00  2020-04-13T09:00:00      8464000.0
# 197  KRW-BTC  2020-04-06T00:00:00  2020-04-06T09:00:00      8198000.0
# 198  KRW-BTC  2020-03-30T00:00:00  2020-03-30T09:00:00      7218000.0
# 199  KRW-BTC  2020-03-23T00:00:00  2020-03-23T09:00:00      7379000.0
#
#      high_price   low_price  trade_price      timestamp  \
# 0    59577000.0  55935000.0   57485000.0  1705810819376
# ...
